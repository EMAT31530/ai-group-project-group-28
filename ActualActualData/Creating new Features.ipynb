# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
df = pd.read_csv('training_set.csv')
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  sep_status  aug_status  \
# 0   0.040404  0.0   0.333333       0.0  0.344828         0.2         0.2
# 1   0.090909  0.0   0.666667       0.0  0.258621         0.4         0.2
# 2   0.121212  1.0   0.333333       0.5  0.068966         0.2         0.2
# 3   0.151515  0.0   0.333333       0.5  0.120690         0.1         0.1
# 4   0.121212  0.0   0.000000       0.5  0.068966         0.1         0.1
#
#    jul_status  jun_status  may_status  ...  jun_bill  may_bill  apr_bill  \
# 0         0.2         0.2         0.2  ...  0.171654  0.091738  0.268766
# 1         0.2         0.4         0.2  ...  0.265655  0.192602  0.353274
# 2         0.2         0.2         0.2  ...  0.165034  0.085802  0.264973
# 3         0.1         0.2         0.2  ...  0.163882  0.084337  0.265334
# 4         0.1         0.1         0.1  ...  0.161160  0.081587  0.261359
#
#    sep_payment  aug_payment  jul_payment  jun_payment  may_payment  \
# ...

# %%
X, y = df.iloc[:,:-1], df.iloc[:, -1]

# %%
#SMOTE
sm = SMOTE(random_state=0)
X_smote, y_smote = sm.fit_resample(X,y)

X_smote['default.payment.next.month'] = y_smote

# %%
#RandomOverSample
ros = RandomOverSampler(random_state=0)
X_ros, y_ros = ros.fit_resample(X,y)

X_ros['default.payment.next.month'] = y_ros

# %%
#RandomOverSample
rus = RandomUnderSampler(random_state=0)
X_rus, y_rus = rus.fit_resample(X,y)

X_rus['default.payment.next.month'] = y_rus

# %%
print(df['default.payment.next.month'].value_counts())
print(X_smote['default.payment.next.month'].value_counts())
print(X_ros['default.payment.next.month'].value_counts())
print(X_rus['default.payment.next.month'].value_counts())
# Out:
# 0.0    16355
# 1.0     4645
# Name: default.payment.next.month, dtype: int64
# 0.0    16355
# 1.0    16355
# Name: default.payment.next.month, dtype: int64
# 0.0    16355
# 1.0    16355
# Name: default.payment.next.month, dtype: int64
# 0.0    4645
# 1.0    4645
# Name: default.payment.next.month, dtype: int64

# %%
X_ros.to_csv('training_ROS.csv', index=False)
X_rus.to_csv('training_RUS.csv', index=False)
X_smote.to_csv('training_SMOTE.csv', index=False)
