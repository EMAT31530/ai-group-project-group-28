# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('UCI_Credit_Card.csv')
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %% [markdown]
#  (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above)

# %%
fig, ax = plt.subplots(figsize=(25, 25))
sns.heatmap(
        df.corr(), 
        cmap = sns.diverging_palette(220, 10, as_cmap = True),
        square=True, 
        cbar=False,
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 })
plt.show()

# %%
df['default.payment.next.month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default.payment.next.month, dtype: int64

# %%
df = df.drop(columns=['ID'])

# %%
df['SEX'] = df['SEX'].replace({2:0})

# %%
df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    0          2         1   24      2      2     -1     -1
# 1       120000.0    0          2         2   26     -1      2      0      0
# 2        90000.0    0          2         2   34      0      0      0      0
# 3        50000.0    0          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# 29999    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %%
print(df['EDUCATION'].value_counts())
df['EDUCATION'] = df['EDUCATION'].replace({5:4 , 6:4 , 0:4})
df
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    0          2         1   24      2      2     -1     -1
# 1       120000.0    0          2         2   26     -1      2      0      0
# 2        90000.0    0          2         2   34      0      0      0      0
# 3        50000.0    0          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# ...

# %%
print(df['MARRIAGE'].value_counts())
df['MARRIAGE'] = df['MARRIAGE'].replace({0:3})
df
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    0          2         1   24      2      2     -1     -1
# 1       120000.0    0          2         2   26     -1      2      0      0
# 2        90000.0    0          2         2   34      0      0      0      0
# 3        50000.0    0          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# ...

# %%
df.columns
df = df.rename(columns={'PAY_0': 'sep_status', 'PAY_2': 'aug_status', 
                        'PAY_3': 'jul_status' , 'PAY_4' : 'jun_status' , 
                        'PAY_5' : 'may_status' , 'PAY_6' : 'apr_status'})
df = df.rename(columns={'BILL_AMT1': 'sep_bill', 'BILL_AMT2': 'aug_bill', 
                        'BILL_AMT3': 'jul_bill' , 'BILL_AMT4' : 'jun_bill' ,
                        'BILL_AMT5' : 'may_bill' , 'BILL_AMT6' : 'apr_bill'})
df = df.rename(columns={'PAY_AMT1': 'sep_payment', 'PAY_AMT2': 'aug_payment', 
                        'PAY_AMT3': 'jul_payment' , 'PAY_AMT4' : 'jun_payment' ,
                        'PAY_AMT5' : 'may_payment' , 'PAY_AMT6' : 'apr_payment'})
df.iloc[1]
# Out:
# LIMIT_BAL                     120000.0
# SEX                                0.0
# EDUCATION                          2.0
# MARRIAGE                           2.0
# AGE                               26.0
# sep_status                        -1.0
# aug_status                         2.0
# jul_status                         0.0
# jun_status                         0.0
# may_status                         0.0
# apr_status                         2.0
# sep_bill                        2682.0
# aug_bill                        1725.0
# jul_bill                        2682.0
# jun_bill                        3272.0
# may_bill                        3455.0
# apr_bill                        3261.0
# sep_payment                        0.0
# aug_payment                     1000.0
# jul_payment                     1000.0
# jun_payment                     1000.0
# may_payment                        0.0
# apr_payment                     2000.0
# default.payment.next.month         1.0
# ...

# %%
df['sep_status'].value_counts()
# Out:
#  0    14737
# -1     5686
#  1     3688
# -2     2759
#  2     2667
#  3      322
#  4       76
#  5       26
#  8       19
#  6       11
#  7        9
# Name: sep_status, dtype: int64

# %%
normalized_df[LII=(df-df.min())/(df.max()-df.min())

# %%
normalized_df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  sep_status  aug_status  \
# 0       0.010101  0.0   0.333333       0.0  0.051724         0.4         0.4
# 1       0.111111  0.0   0.333333       0.5  0.086207         0.1         0.4
# 2       0.080808  0.0   0.333333       0.5  0.224138         0.2         0.2
# 3       0.040404  0.0   0.333333       0.0  0.275862         0.2         0.2
# 4       0.040404  1.0   0.333333       0.0  0.620690         0.1         0.2
# ...          ...  ...        ...       ...       ...         ...         ...
# 29995   0.212121  1.0   0.666667       0.0  0.310345         0.2         0.2
# 29996   0.141414  1.0   0.666667       0.5  0.379310         0.1         0.1
# 29997   0.020202  1.0   0.333333       0.5  0.275862         0.6         0.5
# 29998   0.070707  1.0   0.666667       0.0  0.344828         0.3         0.1
# 29999   0.040404  1.0   0.333333       0.0  0.431034         0.2         0.2
#
# ...

# %%
normalized_df.to_csv('normalised_clean_data.csv', index=False)

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('normalised_clean_data.csv')

# %%
df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  sep_status  aug_status  \
# 0       0.010101  0.0   0.333333       0.0  0.051724         0.4         0.4
# 1       0.111111  0.0   0.333333       0.5  0.086207         0.1         0.4
# 2       0.080808  0.0   0.333333       0.5  0.224138         0.2         0.2
# 3       0.040404  0.0   0.333333       0.0  0.275862         0.2         0.2
# 4       0.040404  1.0   0.333333       0.0  0.620690         0.1         0.2
# ...          ...  ...        ...       ...       ...         ...         ...
# 29995   0.212121  1.0   0.666667       0.0  0.310345         0.2         0.2
# 29996   0.141414  1.0   0.666667       0.5  0.379310         0.1         0.1
# 29997   0.020202  1.0   0.333333       0.5  0.275862         0.6         0.5
# 29998   0.070707  1.0   0.666667       0.0  0.344828         0.3         0.1
# 29999   0.040404  1.0   0.333333       0.0  0.431034         0.2         0.2
#
# ...

# %%
df_train, df_test_valid = train_test_split( df ,stratify=df['default.payment.next.month'], test_size=0.3)
df_test, df_validation = train_test_split( df_test_valid, stratify=df_test_valid['default.payment.next.month'], test_size=0.5)

# %%
df_train
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  sep_status  aug_status  \
# 16129   0.040404  0.0   0.333333       0.0  0.344828         0.2         0.2
# 22433   0.090909  0.0   0.666667       0.0  0.258621         0.4         0.2
# 12566   0.121212  1.0   0.333333       0.5  0.068966         0.2         0.2
# 15215   0.151515  0.0   0.333333       0.5  0.120690         0.1         0.1
# 4122    0.121212  0.0   0.000000       0.5  0.068966         0.1         0.1
# ...          ...  ...        ...       ...       ...         ...         ...
# 14960   0.161616  0.0   0.333333       0.5  0.189655         0.2         0.2
# 7582    0.090909  0.0   0.000000       0.0  0.189655         0.1         0.1
# 5015    0.282828  0.0   0.000000       0.5  0.051724         0.3         0.0
# 22635   0.292929  0.0   0.333333       0.5  0.448276         0.2         0.2
# 9412    0.040404  1.0   0.666667       0.5  0.034483         0.3         0.0
#
# ...

# %%
df_train.to_csv('training_set.csv', index=False)
df_validation.to_csv('validation_set.csv', index=False)
df_test.to_csv('test_set.csv', index=False)
